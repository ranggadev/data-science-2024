# %% [markdown]
# Nama Lengkap : Rangga Saputra
#
# NIM : 250401020034
#
# Kelas : IF405
#
# ---
#
# # Praktikum Pertemuan 1: Pengenalan Data Science

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Rangga Saputra" # String
angkatan = 2025 # Integer
ipk = 3.87 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Rangga Saputra
# Angkatan: 2025
# IPK : 3.87
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
#SEL 4 : Fungsi Sederhana
def perkenalan (nama,prodi,angkatan) :
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, Angkatan {angkatan}."

hasil = perkenalan ("Rangga Saputra", "PJJ Informatika", "2025")
print (hasil)
# Out:
# Hai! Saya Rangga Saputra dari PJJ Informatika, Angkatan 2025.

# %% [markdown]
# ## Kesimpulan:
#
# ### Apa yang Dipelajari
# Pada pertemuan pertama ini, saya mempelajari dasar-dasar pemrograman Python sebagai fondasi dalam praktik Data Science. Yang dipelajari sebagai berikut:
# - Penggunaan Google Colab sebagai lingkungan pengembangan berbasis cloud
# - Penulisan output menggunakan fungsi `print()`
# - Tipe data dasar Python: **String**, **Integer**, **Float**, dan **Boolean**
# - Struktur data **List** dan iterasi menggunakan perulangan `for`
# - Pembuatan **fungsi** sederhana dengan parameter dan return value
#
# ### Temuan Utama
# - Python memiliki sintaks yang ringkas dan mudah dibaca, sehingga ideal untuk analisis data
# - Google Colab dapat melakukan eksekusi kode Python langsung di browser tanpa instalasi di lokal komputer, sangat praktis untuk pembelajaran
# - Fungsi (`def`) membantu membuat kode lebih terstruktur dan dapat digunakan kembali
#
# ### Keterbatasan & Pertanyaan yang Muncul
# - Praktikum ini masih dasar dan belum mendalam seperti penggunaan library Data Science seperti Pandas, NumPy, atau Matplotlib
# - Karena masih awal dan awam, saya penasan bagaimana nanti tools-tools semacam ini bisa diterapkan dalam pekerjaan saya tentang kehumasan dan media sosial.
